# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

# %%
    "0x430c8c4a0a8f1c5a9de3576dcd153dd2b68c0d67",
    "0x3183ace137a96108292e58df284bbaaa6bca3b8a",
    "0x6d191737f9653a66d0e8236fff6e8ea543c05bc0",
    "0x8b1396f754b83afa1d06d273d5915d573b4f04ee",
    "0xf537776e58076ec7f50fe945c9384480816daa6d",
    "0x185737db359230898bf324d07de25160c71948b2",
    "0x1488bcfff8f7edd8286bf9549a76c8c7f10c829f",
    "0xfcbb6faac5f65ffe74e32ef4896b7ae5f5b35f0f",
    "0xa0b9faac81f34a849d57516a0193b37ec23e70b8",
    "0x1a5918dd41efcc34aba03c40b86242d10bc398fa",
    "0x1111e3ef0b6ae32e14a55e0e7cd9b8505177c2bf",
    "0xb16c60e0a93b73cd96bca5b0811715146b3f6fb4",
    "0x26a474cd0448b0d46487c811069b87a1f6d5dad6",
    "0xac411ce0f1a294544eee0922bfdfb64459301822",
    "0x89639b0c40b8517145d238df4a5a83247ebb66a5",
    "0x276bf434613bd8cb5c8b3282ec6445c9370e33fa",
    "0xd51ce9be4a1cb6185b76ba825c59236a6cf5ca2a",
    "0x3cfee83db8ddddc463c98d1224825a70de14a601",
    "0xb0bc44ca9ef6eb6f4eaac6807c9f6307f8136497"
# Out:
# '0xb0bc44ca9ef6eb6f4eaac6807c9f6307f8136497'

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import time

# Wallet addresses
wallet_addresses = [
"0x6ae04d64c0fd3bd5bae3150c763c7d7beb851c0d",
"0xedC6BacdC1e29D7c5FA6f6ECA6FDD447B9C487c9",
"0xabc74170f3Cb8Ab352820C39cC1d1e05cE9e41D3",
"0xfb9779477e5b4834bf2bc02dd29b97b344d0f700",
"0x8e8f818d3371f797a2db7edb32803607c8b3c6a9",
"0xe99bc90d3cb86cf095d75a020c10fbf9d4aa9a4d",
"0xd66570edcdade24edda902b28f2172e9ef8395dd",
"0x311d03143384cce04082800056a5f0c38f7f997b",
"0x032Ce235e0884Cd671E3D5B4B3983822A5F6740d",
"0x17b4051556118ed22424b9230725b08e4acd939f",
"0xa57e55ec968aaf937c4df7179cc884381b684c28",
"0xe97881a663a97b1fecbfe51a6318f2d53c7a49cd",
"0x4f3c217ea13940524ef2b11c4b0efecd117a9e37",
"0x008300082c3000009e63680088f8c7f4d3ff2e87",
"0x93793bd1f3e35a0efd098c30e486a860a0ef7551",
"0xc05f4c75465c6b1cfd4ffd1d8ce91c74a5563d5f",
"0x4f36327b71c99293d827d90d1b39e8a5aa672864",
"0x8b1396f754b83afa1d06d273d5915d573b4f04ee",
"0x8b1396f754b83afa1d06d273d5915d573b4f04ee"
]

# Etherscan API key
api_key = "5DSDMCYD46MENP7TZPUUDYBIDH1A2U6GB5"

# Define start and end block variables
start_block = 0  # Replace with the actual start block number
end_block = 999999999999  # Replace with the actual end block number

def get_token_transfers(wallet_address):
    url = f"https://api.etherscan.io/api"
    params = {
        "module": "account",
        "action": "tokentx",
        "address": wallet_address,
        "startblock": start_block,
        "endblock": end_block,
        "sort": "asc",
        "apikey": api_key,
    }
    response = requests.get(url, params=params)
    data = response.json()
    if data["status"] == "1":
        return data["result"]
    else:
        return []

# Pulling token transfer data for each wallet
all_token_transfers = []

for wallet in wallet_addresses:
    print(f"Pulling token transfers for wallet: {wallet}")
    token_transfers = get_token_transfers(wallet)
    all_token_transfers.extend(token_transfers)
    time.sleep(1)  # To avoid hitting rate limits

# Creating DataFrame from token transfers
df = pd.DataFrame(all_token_transfers)
# Out:
# Pulling token transfers for wallet: 0x6ae04d64c0fd3bd5bae3150c763c7d7beb851c0d
# Pulling token transfers for wallet: 0xedC6BacdC1e29D7c5FA6f6ECA6FDD447B9C487c9
# Pulling token transfers for wallet: 0xabc74170f3Cb8Ab352820C39cC1d1e05cE9e41D3
# Pulling token transfers for wallet: 0xfb9779477e5b4834bf2bc02dd29b97b344d0f700
# Pulling token transfers for wallet: 0x8e8f818d3371f797a2db7edb32803607c8b3c6a9
# Pulling token transfers for wallet: 0xe99bc90d3cb86cf095d75a020c10fbf9d4aa9a4d
# Pulling token transfers for wallet: 0xd66570edcdade24edda902b28f2172e9ef8395dd
# Pulling token transfers for wallet: 0x311d03143384cce04082800056a5f0c38f7f997b
# Pulling token transfers for wallet: 0x032Ce235e0884Cd671E3D5B4B3983822A5F6740d
# Pulling token transfers for wallet: 0x17b4051556118ed22424b9230725b08e4acd939f
# Pulling token transfers for wallet: 0xa57e55ec968aaf937c4df7179cc884381b684c28
# Pulling token transfers for wallet: 0xe97881a663a97b1fecbfe51a6318f2d53c7a49cd
# Pulling token transfers for wallet: 0x4f3c217ea13940524ef2b11c4b0efecd117a9e37
# Pulling token transfers for wallet: 0x008300082c3000009e63680088f8c7f4d3ff2e87
# Pulling token transfers for wallet: 0x93793bd1f3e35a0efd098c30e486a860a0ef7551
# Pulling token transfers for wallet: 0xc05f4c75465c6b1cfd4ffd1d8ce91c74a5563d5f
# Pulling token transfers for wallet: 0x4f36327b71c99293d827d90d1b39e8a5aa672864
# Pulling token transfers for wallet: 0x8b1396f754b83afa1d06d273d5915d573b4f04ee
# Pulling token transfers for wallet: 0x8b1396f754b83afa1d06d273d5915d573b4f04ee

# %%
df
# Out:
#       blockNumber   timeStamp  \
# 0        18479794  1698872351
# 1        13191681  1631192623
# 2        13191683  1631192664
# 3        13191687  1631192681
# 4        13191688  1631192698
# ...           ...         ...
# 29745    21332642  1733357579
# 29746    21332648  1733357663
# 29747    21332963  1733361479
# 29748    21334806  1733383751
# 29749    21337858  1733420579
#
#                                                     hash    nonce  \
# 0      0x0934c51b44ca7c589ac0073ebc7841c0ac2462365511...  1023571
# 1      0x66e67909a32c02e904867704bd7a0a7ee78739594d38...    91996
# 2      0xd56245f308b30a911dc7584a6f8c5d2e6ee6ce8817e9...    91997
# 3      0xd72295d4e1dc94d77663a41cc423b1576a9033f41488...    91998
# 4      0xfa8f45b31a432daf31c72a3b2ddfd280e51c98b0ad25...    91999
# 4      0xedc6bacdc1e29d7c5fa6f6eca6fdd447b9c487c9   1000000000000000000
# ...                                           ...                   ...
# 29745  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  36500000000000000000
# 29746  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  86500000000000000000
# 29747  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  53500000000000000000
# 29748  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  66866550000000000000
# 29749  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  77900000000000000000
#
#            tokenName tokenSymbol tokenDecimal transactionIndex      gas  \
# 0         Tether USD        USDT            6              107  2000000
# 1         Tether USD        USDT            6              200   250000
# 2                ELF         ELF           18               44   250000
# 3          HoloToken         HOT           18               63   250000
# 4      StatusNetwork         SNT           18              175   250000
# ...              ...         ...          ...              ...      ...
# 29745      Nvidia AI   NVIDIA AI            8              100   276131
# 29746       Tesla AI    TESLA AI            8              101   466135
# 29747       Tesla AI    TESLA AI            8              149   710933
# 29748      Nvidia AI   NVIDIA AI            8              229   995879
# 29749  Haito Finance       HAITO            9                3  1332540
#
#            gasPrice gasUsed cumulativeGasUsed       input confirmations
# 0       51860172670  385605          10512411  deprecated       2858091
# 1      141741969029   63197          23704548  deprecated       8146204
# 2      155624912859   54452           2719870  deprecated       8146202
# 3      137591603647   54417           3085716  deprecated       8146198
# 4      121993521393  119675          12315818  deprecated       8146197
# ...             ...     ...               ...         ...           ...
# 29745   23125891036  272799          10018450  deprecated          5246
# 29746   23429235443  461307          10344939  deprecated          5240
# 29747   20740241784  704177          11688898  deprecated          4925
# 29748   14765461329  986879          20201138  deprecated          3082
# 29749   26580822978  880207           3898846  deprecated            30
#
# [29750 rows x 19 columns]

# %%
# Ensure we only keep necessary columns
df = df[["timeStamp", "hash", "from", "contractAddress", "to",  "tokenName", "tokenSymbol", "value"]]
df["timeStamp"] = pd.to_datetime(df["timeStamp"], unit='s')

# Define seven_days_ago variable
seven_days_ago = pd.Timestamp.now() - pd.Timedelta(days=7)

# Filtering token transactions within the past 1 days
df = df[df["timeStamp"] >= seven_days_ago]
# Out:
# /var/folders/bc/69frl30s4xv269mkcmjkv2qr0000gn/T/ipykernel_73931/3816293258.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df["timeStamp"] = pd.to_datetime(df["timeStamp"], unit='s')
# /var/folders/bc/69frl30s4xv269mkcmjkv2qr0000gn/T/ipykernel_73931/3816293258.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["timeStamp"] = pd.to_datetime(df["timeStamp"], unit='s')

# %%
df
# Out:
#                 timeStamp                                               hash  \
# 7649  2024-11-28 15:08:48  0x582629f26b088a43c651dc9a88aae9f5befb119dc6c6...
# 7650  2024-11-28 15:10:56  0x5ec2790bc316cad7c2c92c8058e199612553190c248e...
# 7651  2024-11-28 15:38:40  0x192a53111cc2655fb30b9f87baa42338ae75db7c3264...
# 7652  2024-11-28 18:29:20  0x2f32f10d6bb53e0485e9f546b64ad7708126c83be29a...
# 7653  2024-11-28 21:09:20  0x171d72aa0a454232b860c1242b6f003fc4ebddf74dc7...
# 29749  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  Haito Finance       HAITO
#
#                             value
# 7649    3800000000000000000000000
# 7650     240000000000000000000000
# 7651    8000000000000000000000000
# 7652   14638473810000000000000000
# 7653     800000000000000000000000
# ...                           ...
# 29745        36500000000000000000
# 29746        86500000000000000000
# 29747        53500000000000000000
# 29748        66866550000000000000
# 29749        77900000000000000000
#
# [770 rows x 8 columns]

# %%
api_columns = [
    "price",  "price5m", "variation5m", 
    "price1h", "variation1h", 
    "price6h", "variation6h", 
    "price24h", "variation24h"
]

# Set up API request
headers = {
    "accept": "application/json",
    "x-api-key": "uo9IKArCoh5aH9tNo3OBj6JwaQhjuuFLaWxLNuOW"
}

def get_token_data(contract_address):
    url = f"https://public-api.dextools.io/trial/v2/token/ether/{contract_address}/price"
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        if 'data' in data and data['data']:
            # Extract only the specified metrics
            token_data = {col: data['data'].get(col, None) for col in api_columns}
            # Check if any data is missing and log it
            missing_data = [col for col, value in token_data.items() if value is None]
            if missing_data:
                print(f"Missing data for {contract_address}: {missing_data}")
            return token_data
        else:
            print(f"No data returned for {contract_address}. Response content: {data}")
            return {col: None for col in api_columns}
            
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {contract_address}: {e}")
        return {col: None for col in api_columns}
    
    # Add rate limiting
    time.sleep(1)

# Process each unique contract in the DataFrame
unique_contracts = df['contractAddress'].str.lower().unique()
for contract in unique_contracts:
    token_data = get_token_data(contract)
    
    # Update DataFrame with token data
    for col, value in token_data.items():
        df.loc[df['contractAddress'].str.lower() == contract, f'dextools_{col}'] = value

# Convert columns to numeric
for col in [f'dextools_{c}' for c in api_columns]:
    df[col] = pd.to_numeric(df[col], errors='coerce')
# Out:
# Missing data for 0x80c62fe4487e1351b47ba49809ebd60ed085bf52: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Missing data for 0xa62cc35625b0c8dc1faea39d33625bb4c15bd71c: ['price5m', 'variation5m']
# Error fetching data for 0xbe0ed4138121ecfc5c0e56b40517da27e6c5226b: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xbe0ed4138121ecfc5c0e56b40517da27e6c5226b/price
# Error fetching data for 0x744d70fdbe2ba4cf95131626614a1763df805b9e: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x744d70fdbe2ba4cf95131626614a1763df805b9e/price
# Error fetching data for 0xd3aef756e77ff56d2efcdc8bbb84674038da42ac: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xd3aef756e77ff56d2efcdc8bbb84674038da42ac/price
# Error fetching data for 0x55d0c027569318f819e81718e484862e6556766a: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x55d0c027569318f819e81718e484862e6556766a/price
# Error fetching data for 0x37843bc944edbb0477df943d9061d359004a4e70: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x37843bc944edbb0477df943d9061d359004a4e70/price
# Error fetching data for 0xdba22db98d9651e7d11b811476b0c7c563d7ff84: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xdba22db98d9651e7d11b811476b0c7c563d7ff84/price
# Error fetching data for 0x163f8c2467924be0ae7b5347228cabf260318753: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x163f8c2467924be0ae7b5347228cabf260318753/price
# Error fetching data for 0xdef1ca1fb7fbcdc777520aa7f396b4e015f497ab: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xdef1ca1fb7fbcdc777520aa7f396b4e015f497ab/price
# Error fetching data for 0xbf2179859fc6d5bee9bf9158632dc51678a4100e: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0
 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x619ef615fc1ef0c9e066b233ddbf50e5a9ad3de4/price
# Error fetching data for 0x3739426e21d912b604c106f852d136ba58f61517: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x3739426e21d912b604c106f852d136ba58f61517/price

# %%
# Define the columns we want to capture from the info API endpoint
info_columns = [
    "circulatingSupply", "totalSupply", "mcap", "fdv", "holders"
]

def get_token_info(contract_address):
    url = f"https://public-api.dextools.io/trial/v2/token/ether/{contract_address}/info"
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        if 'data' in data and data['data']:
            # Extract only the specified metrics
            token_info = {col: data['data'].get(col, None) for col in info_columns}
            # Check if any data is missing and log it
            missing_data = [col for col, value in token_info.items() if value is None]
            if missing_data:
                print(f"Missing info data for {contract_address}: {missing_data}")
            return token_info
        else:
            print(f"No info data returned for {contract_address}. Response content: {data}")
            return {col: None for col in info_columns}
            
    except requests.exceptions.RequestException as e:
        print(f"Error fetching info data for {contract_address}: {e}")
        return {col: None for col in info_columns}
    
    # Add rate limiting
    time.sleep(1)

# Process each unique contract in the DataFrame
unique_contracts = df['contractAddress'].str.lower().unique()
for contract in unique_contracts:
    token_info = get_token_info(contract)
    
    # Update DataFrame with token info
    for col, value in token_info.items():
        df.loc[df['contractAddress'].str.lower() == contract, f'dextools_{col}'] = value

# Convert columns to numeric
for col in [f'dextools_{c}' for c in info_columns]:
    df[col] = pd.to_numeric(df[col], errors='coerce')
# Out:
# Missing info data for 0xd3aef756e77ff56d2efcdc8bbb84674038da42ac: ['circulatingSupply', 'mcap']
# Missing info data for 0x55d0c027569318f819e81718e484862e6556766a: ['circulatingSupply', 'mcap']
# Missing info data for 0x37843bc944edbb0477df943d9061d359004a4e70: ['circulatingSupply', 'mcap']
# Missing info data for 0xdba22db98d9651e7d11b811476b0c7c563d7ff84: ['circulatingSupply', 'mcap']
# Error fetching info data for 0x36c224af80207ecaba3ee9052faaba56d1f50c18: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x36c224af80207ecaba3ee9052faaba56d1f50c18/info
# Error fetching info data for 0x53dac5b23b3ca9a3c86aff8d0c7110fba72a9783: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x53dac5b23b3ca9a3c86aff8d0c7110fba72a9783/info
# Error fetching info data for 0xc7e8c1ff4afdfc47ff9885627afe9a3fa2d7c65b: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xc7e8c1ff4afdfc47ff9885627afe9a3fa2d7c65b/info
# Error fetching info data for 0x6982508145454ce325ddbe47a25d4ec3d2311933: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x6982508145454ce325ddbe47a25d4ec3d2311933/info
# Error fetching info data for 0xe3a9640f959c5aa92dbfac0073180903c30af29c: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xe3a9640f959c5aa92dbfac0073180903c30af29c/info
# Error fetching info data for 0x8475ec8b519025548c2417b82aa25bf58cd72b39: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x8475ec8b519025548c2417b82aa25bf58cd72b39/info
# Error fetching info data for 0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9/info
# Error fetching info data for 0x320623b8e4ff03373931769a31fc52a4e78b5d70: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x320623b8e4ff03373931769a31fc52a4e78b5d70/info
# Error fetching info data for 0x628a3b2e302c7e896acc432d2d0dd22b6cb9bc88: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0
 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x22285458758ac560b63ba223eb8450f821e0198c/info
# Error fetching info data for 0x1121acc14c63f3c872bfca497d10926a6098aac5: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x1121acc14c63f3c872bfca497d10926a6098aac5/info
# Error fetching info data for 0x812ba41e071c7b7fa4ebcfb62df5f45f6fa853ee: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x812ba41e071c7b7fa4ebcfb62df5f45f6fa853ee/info
# Error fetching info data for 0x8baf5d75cae25c7df6d1e0d26c52d19ee848301a: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x8baf5d75cae25c7df6d1e0d26c52d19ee848301a/info
# Error fetching info data for 0xed89fc0f41d8be2c98b13b7e3cd3e876d73f1d30: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0xed89fc0f41d8be2c98b13b7e3cd3e876d73f1d30/info
# Error fetching info data for 0x8ed97a637a790be1feff5e888d43629dc05408f6: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x8ed97a637a790be1feff5e888d43629dc05408f6/info
# Error fetching info data for 0x7539d2ea6fc2e289d7ce9ecb7a66e37bf12d87c0: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x7539d2ea6fc2e289d7ce9ecb7a66e37bf12d87c0/info
# Error fetching info data for 0x14a16a0abc0c00bbc1cf240c14c43dd42697a554: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x14a16a0abc0c00bbc1cf240c14c43dd42697a554/info
# Error fetching info data for 0x619ef615fc1ef0c9e066b233ddbf50e5a9ad3de4: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x619ef615fc1ef0c9e066b233ddbf50e5a9ad3de4/info
# Error fetching info data for 0x3739426e21d912b604c106f852d136ba58f61517: 429 Client Error: Too Many Requests for url: https://public-api.dextools.io/trial/v2/token/ether/0x3739426e21d912b604c106f852d136ba58f61517/info

# %%
def get_token_info(contract_address):
    url = f"https://public-api.dextools.io/trial/v2/token/ether/{contract_address}/info"
    
    try:
        # Add exponential backoff retry logic
        max_retries = 3
        retry_delay = 5  # Start with 5 seconds
        
        for attempt in range(max_retries):
            response = requests.get(url, headers=headers)
            
            if response.status_code == 200:
                data = response.json()
                if 'data' in data and data['data']:
                    token_info = {col: data['data'].get(col, None) for col in info_columns}
                    return token_info
                else:
                    print(f"No info data returned for {contract_address}")
                    return {col: None for col in info_columns}
            
            elif response.status_code == 429:  # Too Many Requests
                if attempt < max_retries - 1:  # Don't sleep on last attempt
                    sleep_time = retry_delay * (2 ** attempt)  # Exponential backoff
                    print(f"Rate limit hit, waiting {sleep_time} seconds...")
                    time.sleep(sleep_time)
                    continue
            
            else:
                print(f"Error {response.status_code} for {contract_address}")
                return {col: None for col in info_columns}
                
    except requests.exceptions.RequestException as e:
        print(f"Error fetching info data for {contract_address}: {e}")
        return {col: None for col in info_columns}
    
    # Add longer delay between successful requests
    time.sleep(2)

# Process contracts in smaller batches
batch_size = 5
for i in range(0, len(unique_contracts), batch_size):
    batch = unique_contracts[i:i+batch_size]
    print(f"Processing batch {i//batch_size + 1}/{len(unique_contracts)//batch_size + 1}")
    
    for contract in batch:
        token_info = get_token_info(contract)
        
        # Update DataFrame with token info
        for col, value in token_info.items():
            df.loc[df['contractAddress'].str.lower() == contract, f'dextools_{col}'] = value
    
    # Add delay between batches
    time.sleep(10)  # Wait 10 seconds between batches
# Out:
# Processing batch 1/13
# Processing batch 2/13
# Processing batch 3/13
# Processing batch 4/13
# Processing batch 5/13
# Processing batch 6/13
# Processing batch 7/13
# Processing batch 8/13
# Processing batch 9/13
# Processing batch 10/13
# Processing batch 11/13
# Processing batch 12/13
# Processing batch 13/13

# %%
def get_token_data(contract_address):
    url = f"https://public-api.dextools.io/trial/v2/token/ether/{contract_address}/price"
    
    try:
        # Add exponential backoff retry logic
        max_retries = 3
        retry_delay = 5  # Start with 5 seconds
        
        for attempt in range(max_retries):
            response = requests.get(url, headers=headers)
            
            if response.status_code == 200:
                data = response.json()
                if 'data' in data and data['data']:
                    # Extract only the specified metrics
                    token_data = {col: data['data'].get(col, None) for col in api_columns}
                    # Check if any data is missing and log it
                    missing_data = [col for col, value in token_data.items() if value is None]
                    if missing_data:
                        print(f"Missing data for {contract_address}: {missing_data}")
                    return token_data
                else:
                    print(f"No data returned for {contract_address}")
                    return {col: None for col in api_columns}
            
            elif response.status_code == 429:  # Too Many Requests
                if attempt < max_retries - 1:  # Don't sleep on last attempt
                    sleep_time = retry_delay * (2 ** attempt)  # Exponential backoff
                    print(f"Rate limit hit, waiting {sleep_time} seconds...")
                    time.sleep(sleep_time)
                    continue
            
            else:
                print(f"Error {response.status_code} for {contract_address}")
                return {col: None for col in api_columns}
                
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {contract_address}: {e}")
        return {col: None for col in api_columns}
    
    # Add longer delay between successful requests
    time.sleep(2)

# Process contracts in smaller batches
batch_size = 5
unique_contracts = df['contractAddress'].str.lower().unique()

for i in range(0, len(unique_contracts), batch_size):
    batch = unique_contracts[i:i+batch_size]
    print(f"Processing batch {i//batch_size + 1}/{len(unique_contracts)//batch_size + 1}")
    
    for contract in batch:
        token_data = get_token_data(contract)
        
        # Update DataFrame with token data
        for col, value in token_data.items():
            df.loc[df['contractAddress'].str.lower() == contract, f'dextools_{col}'] = value
    
    # Add delay between batches
    time.sleep(10)  # Wait 10 seconds between batches

# Convert columns to numeric
for col in [f'dextools_{c}' for c in api_columns]:
    df[col] = pd.to_numeric(df[col], errors='coerce')
# Out:
# Processing batch 1/13
# Missing data for 0x80c62fe4487e1351b47ba49809ebd60ed085bf52: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Missing data for 0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55: ['price5m', 'variation5m']
# Rate limit hit, waiting 5 seconds...
# Missing data for 0x744d70fdbe2ba4cf95131626614a1763df805b9e: ['price5m', 'variation5m']
# Processing batch 2/13
# Missing data for 0xd3aef756e77ff56d2efcdc8bbb84674038da42ac: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0x55d0c027569318f819e81718e484862e6556766a: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0x37843bc944edbb0477df943d9061d359004a4e70: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Missing data for 0xdba22db98d9651e7d11b811476b0c7c563d7ff84: ['price5m', 'variation5m', 'price6h', 'variation6h']
# Missing data for 0x163f8c2467924be0ae7b5347228cabf260318753: ['price5m', 'variation5m']
# Processing batch 3/13
# Missing data for 0xdef1ca1fb7fbcdc777520aa7f396b4e015f497ab: ['price5m', 'variation5m']
# Missing data for 0xbf2179859fc6d5bee9bf9158632dc51678a4100e: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Missing data for 0x0abdace70d3790235af448c88547603b945604ea: ['price5m', 'variation5m', 'price1h', 'variation1h']
# Missing data for 0x8de5b80a0c1b02fe4976851d030b36122dbb8624: ['price5m', 'variation5m']
# Missing data for 0x36c224af80207ecaba3ee9052faaba56d1f50c18: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Processing batch 4/13
# Missing data for 0x53dac5b23b3ca9a3c86aff8d0c7110fba72a9783: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0xc7e8c1ff4afdfc47ff9885627afe9a3fa2d7c65b: ['price5m', 'variation5m']
# Missing data for 0xe3a9640f959c5aa92dbfac0073180903c30af29c: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0x8475ec8b519025548c2417b82aa25bf58cd72b39: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Processing batch 5/13
# Missing data for 0x320623b8e4ff03373931769a31fc52a4e78b5d70: ['price5m', 'variation5m']
# Missing data for 0x628a3b2e302c7e896acc432d2d0dd22b6cb9bc88: ['price5m', 'variation5m']
# Missing data for 0x78457e3d787c0afea00fb6306f040b476a9393cf: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0xcf0c122c6b73ff809c693db761e7baebe62b6a2e: ['price5m', 'variation5m']
# Processing batch 6/13
# Missing data for 0x1bdf90b9fd1c17146aa26f24cee5094b60b2b660: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Missing data for 0xd533a949740bb3306d119cc777fa900ba034cd52: ['price5m', 'variation5m']
# Missing data for 0xdefa4e8a7bcba345f687a2f1456f5edd9ce97202: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Processing batch 7/13
# Missing data for 0x8f8221afbb33998d8584a2b05749ba73c37a938a: ['price5m', 'variation5m', 'price1h', 'variation1h']
# Missing data for 0x0f2d719407fdbeff09d87557abb7232601fd9f29: ['price5m', 'variation5m']
# Missing data for 0x1bbe973bef3a977fc51cbed703e8ffdefe001fed: ['price5m', 'variation5m']
# Processing batch 8/13
# Missing data for 0x720cd16b011b987da3518fbf38c3071d4f0d1495: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7: ['price5m', 'variation5m']
# Missing data for 0x278b3b1e986eab2d3a33340aeaa362f4b5452f05: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0xd1d2eb1b1e90b638588728b4130137d262c87cae: ['price5m', 'variation5m']
# Missing data for 0xcc8fa225d80b9c7d42f96e9570156c65d6caaa25: ['price5m', 'variation5m']
# Processing batch 9/13
# Missing data for 0xd01409314acb3b245cea9500ece3f6fd4d70ea30: ['price5m', 'variation5m', 'price1h', 'variation1h']
# Missing data for 0x408e41876cccdc0f92210600ef50372656052a38: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0x84ca8bc7997272c7cfb4d0cd3d55cd942b3c9419: ['price1h', 'variation1h']
# Missing data for 0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c: ['price5m', 'variation5m']
# Processing batch 10/13
# Missing data for 0x5afe3855358e112b5647b952709e6165e1c1eeee: ['price5m', 'variation5m']
# Missing data for 0x5ff0d2de4cd862149c6672c99b7edf3b092667a3: ['price5m', 'variation5m']
# Missing data for 0x6cb25129314123bcd5adcdc844ceaeead65a0896: ['price5m', 'variation5m']
# Missing data for 0x641c0f8b889f8336a69f464ddae3733e3de3788a: ['price5m', 'variation5m']
# Processing batch 11/13
# Rate limit hit, waiting 5 seconds...
# Missing data for 0x812ba41e071c7b7fa4ebcfb62df5f45f6fa853ee: ['price5m', 'variation5m']
# Missing data for 0x8baf5d75cae25c7df6d1e0d26c52d19ee848301a: ['price5m', 'variation5m']
# Processing batch 12/13
# Missing data for 0x7539d2ea6fc2e289d7ce9ecb7a66e37bf12d87c0: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h']
# Missing data for 0x14a16a0abc0c00bbc1cf240c14c43dd42697a554: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Missing data for 0x619ef615fc1ef0c9e066b233ddbf50e5a9ad3de4: ['price5m', 'variation5m', 'price1h', 'variation1h', 'price6h', 'variation6h', 'price24h', 'variation24h']
# Processing batch 13/13
# Missing data for 0x3739426e21d912b604c106f852d136ba58f61517: ['price5m', 'variation5m']

# %%
# 1. First, let's check what data we have
print("Columns in DataFrame:", df.columns.tolist())
print("\nSample of numeric columns:")
print(df.describe())

# 2. Clean up any remaining NaN values
df = df.fillna(0)

# 3. Add some useful derived metrics
df['transaction_value_usd'] = df['value'].astype(float) * df['dextools_price']
df['market_cap_millions'] = df['dextools_mcap'] / 1_000_000

# 4. Create a summary of tokens
token_summary = df.groupby(['tokenSymbol', 'contractAddress']).agg({
    'dextools_price': 'last',
    'dextools_mcap': 'last',
    'dextools_holders': 'last',
    'transaction_value_usd': ['count', 'sum', 'mean']
}).round(2)

print("\nToken Summary:")
print(token_summary)

# 5. Save the enriched data
df.to_csv('enriched_token_data.csv', index=False)
token_summary.to_csv('token_summary.csv')

# 6. Optional: Create some visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# Transaction value distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='transaction_value_usd', bins=50)
plt.title('Distribution of Transaction Values')
plt.xlabel('Transaction Value (USD)')
plt.yscale('log')
plt.show()

# Market Cap vs Holders scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['dextools_holders'], df['dextools_mcap'])
plt.xlabel('Number of Holders')
plt.ylabel('Market Cap')
plt.title('Market Cap vs Number of Holders')
plt.yscale('log')
plt.xscale('log')
plt.show()
# Out:
# Columns in DataFrame: ['timeStamp', 'hash', 'from', 'contractAddress', 'to', 'tokenName', 'tokenSymbol', 'value', 'dextools_price', 'dextools_price5m', 'dextools_variation5m', 'dextools_price1h', 'dextools_variation1h', 'dextools_price6h', 'dextools_variation6h', 'dextools_price24h', 'dextools_variation24h', 'dextools_circulatingSupply', 'dextools_totalSupply', 'dextools_mcap', 'dextools_fdv', 'dextools_holders']
#
# Sample of numeric columns:
#                            timeStamp  dextools_price  dextools_price5m  \
# count                            770    7.700000e+02        207.000000
# mean   2024-11-30 23:59:47.033766144    5.728102e+28          2.164254
# min              2024-11-28 12:58:40    1.819453e-09          0.000022
# 25%              2024-11-29 04:20:16    8.821868e-04          0.033104
# 50%              2024-11-30 10:03:44    9.167329e-03          0.297373
# 75%              2024-12-02 02:24:00    7.881724e-02          0.297373
# max              2024-12-05 17:42:24    4.410638e+31        258.895583
# std                              NaN    1.589484e+30         18.387396
#
#        dextools_variation5m  dextools_price1h  dextools_variation1h  \
# count            207.000000      5.230000e+02            523.000000
# mean               1.092531      9.371638e-01              0.009682
# min               -2.104298      1.819453e-09             -9.614599
# 25%                0.056452      7.755109e-03             -3.926564
# 50%                0.056452      2.105473e-02             -0.085517
# 75%                0.056452      3.097012e-01              0.000000
# max               16.968553      2.599592e+02             57.853777
# std                3.893485      1.164759e+01              8.331520
#
#        dextools_price6h  dextools_variation6h  dextools_price24h  \
# count      4.290000e+02            429.000000       6.020000e+02
# mean       1.124568e+00             -0.510813       8.045191e-01
# min        1.722673e-09            -14.344281       1.535991e-09
# 25%        1.800640e-03             -7.520411       2.432171e-03
# 50%        9.166606e-03             -0.207760       1.759991e-02
# 75%        3.217365e-01              0.007888       2.787732e-01
# max        2.562684e+02             64.415603       2.576302e+02
# std        1.267219e+01             11.060476       1.076975e+01
#
#        dextools_variation24h  dextools_circulatingSupply  \
# count             602.000000                3.620000e+02
# mean               99.807226                1.303928e+13
# min               -17.449993                1.500762e+07
# 25%                 5.419235                9.791337e+08
# 50%                 6.732126                1.000000e+09
# 75%                19.629760                4.206898e+11
# max              5302.538665                5.000000e+14
# std               676.941113                7.669460e+13
#
#        dextools_totalSupply  dextools_mcap  dextools_fdv  dextools_holders
# count          7.610000e+02   3.620000e+02  7.610000e+02        770.000000
# mean           6.354281e+12   9.560376e+11  2.550172e+37      20306.428571
# min            1.000000e+07   9.097263e+05  9.146722e+04          0.000000
# 25%            9.999999e+08   2.911676e+08  1.284394e+06         72.000000
# 50%            1.000000e+09   2.911676e+08  2.105473e+07         77.000000
# 75%            1.250000e+10   7.559370e+08  2.911676e+08      26297.000000
# max            5.000000e+14   3.457810e+14  1.940681e+40     724663.000000
# std            5.324619e+13   1.817380e+13  7.034963e+38      70263.370072
#
# Token Summary:
#                                                        dextools_price  \
#                                                                  last
# tokenSymbol contractAddress
# AAVE        0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9         258.40
# AEROBUD     0x37843bc944edbb0477df943d9061d359004a4e70           0.00
# AKRO        0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7           0.01
# ALT         0x8457ca5040ad67fdebbcc8edce889a335bc0fbfb           0.19
# ATH         0xbe0ed4138121ecfc5c0e56b40517da27e6c5226b           0.08
# ...                                                               ...
# TESLA AI    0xdba22db98d9651e7d11b811476b0c7c563d7ff84           0.02
# TURBO       0xa35923162c49cf95e6bf26623385eb431ad920d3           0.01
# VANRY       0x8de5b80a0c1b02fe4976851d030b36122dbb8624           0.18
# WLD         0x163f8c2467924be0ae7b5347228cabf260318753           3.97
# Wally       0x53dac5b23b3ca9a3c86aff8d0c7110fba72a9783           0.00
#
#                                                        dextools_mcap  \
#                                                                 last
# tokenSymbol contractAddress
# AAVE        0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae
# 29748  0xc49d4b479ef7235e62359d1a6fe48c3f65954568
# 29749  0xc1ce1b90a66971e3ea41e911ca03d4ac07952fc4
#
#                                   contractAddress  \
# 7649   0x80c62fe4487e1351b47ba49809ebd60ed085bf52
# 7650   0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55
# 7651   0xa62cc35625b0c8dc1faea39d33625bb4c15bd71c
# 7652   0xbe0ed4138121ecfc5c0e56b40517da27e6c5226b
# 7653   0x744d70fdbe2ba4cf95131626614a1763df805b9e
# ...                                           ...
# 29745  0xc7e8c1ff4afdfc47ff9885627afe9a3fa2d7c65b
# 29746  0xdba22db98d9651e7d11b811476b0c7c563d7ff84
# 29747  0xdba22db98d9651e7d11b811476b0c7c563d7ff84
# 29748  0xc7e8c1ff4afdfc47ff9885627afe9a3fa2d7c65b
# 29749  0x22285458758ac560b63ba223eb8450f821e0198c
#
#                                                to      tokenName tokenSymbol  \
# 7649   0xab782bc7d4a2b306825de5a7730034f8f63ee1bc         Clover         CLV
# 7650   0xab782bc7d4a2b306825de5a7730034f8f63ee1bc     SuperVerse       SUPER
# 7651   0xab782bc7d4a2b306825de5a7730034f8f63ee1bc         StormX        STMX
# 7652   0xedc6bacdc1e29d7c5fa6f6eca6fdd447b9c487c9   Aethir Token         ATH
# 7653   0xab782bc7d4a2b306825de5a7730034f8f63ee1bc  StatusNetwork         SNT
# ...                                           ...            ...         ...
# 29745  0x8b1396f754b83afa1d06d273d5915d573b4f04ee      Nvidia AI   NVIDIA AI
# 29746  0x8b1396f754b83afa1d06d273d5915d573b4f04ee       Tesla AI    TESLA AI
# 29747  0x8b1396f754b83afa1d06d273d5915d573b4f04ee       Tesla AI    TESLA AI
# 29748  0x8b1396f754b83afa1d06d273d5915d573b4f04ee      Nvidia AI   NVIDIA AI
# 29749  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  Haito Finance       HAITO
#
#                             value  dextools_price  dextools_price5m  ...  \
# 7649    3800000000000000000000000        0.126218          0.000000  ...
# 7650     240000000000000000000000        1.745558          0.000000  ...
# 7651    8000000000000000000000000        0.008827          0.007707  ...
# 7652   14638473810000000000000000        0.079256          0.079256  ...
# 7653     800000000000000000000000        0.069089          0.000000  ...
# ...                           ...             ...               ...  ...
# 29745        36500000000000000000        0.009167          0.000000  ...
# 29746        86500000000000000000        0.021055          0.000000  ...
# 29747        53500000000000000000        0.021055          0.000000  ...
# 29748        66866550000000000000        0.009167          0.000000  ...
# 29749        77900000000000000000        0.000106          0.000090  ...
#
#        dextools_variation6h  dextools_price24h  dextools_variation24h  \
# 7649               0.000000           0.106352              18.679720
# 7650              -2.409743           1.624130               7.476461
# 7651              -0.379260           0.007881              12.007352
# 7652               5.918223           0.072449               9.395056
# 7653              -2.897060           0.068820               0.390742
# ...                     ...                ...                    ...
# 29745              0.007888           0.006939              32.122045
# 29746              0.000000           0.017600              19.629760
# 29747              0.000000           0.017600              19.629760
# 29748              0.007888           0.006939              32.122045
# 29749             64.415603           0.000002            5302.538665
#
#        dextools_circulatingSupply  dextools_totalSupply  dextools_mcap  \
# 7649                 1.200000e+08          1.000000e+09   1.514620e+07
# 7650                 4.879761e+08          9.999981e+08   8.517904e+08
# 7651                 1.231841e+10          1.250000e+10   1.059101e+08
# 7652                 5.217818e+09          4.200000e+10   4.135440e+08
# 7653                 3.996915e+09          6.804870e+09   2.761417e+08
# ...                           ...                   ...            ...
# 29745                0.000000e+00          1.000000e+09   0.000000e+00
# 29746                0.000000e+00          1.000000e+09   0.000000e+00
# 29747                0.000000e+00          1.000000e+09   0.000000e+00
# 29748                0.000000e+00          1.000000e+09   0.000000e+00
# 29749                0.000000e+00          1.000000e+10   0.000000e+00
#
#        dextools_fdv  dextools_holders  transaction_value_usd  \
# 7649   1.262183e+08           17671.0           4.796297e+23
# 7650   1.745554e+09           40459.0           4.189338e+23
# 7651   1.074714e+08               0.0           7.061453e+22
# 7652   3.328757e+09           45172.0           1.160189e+24
# 7653   4.701398e+08           82670.0           5.527098e+22
# ...             ...               ...                    ...
# 29745  9.167329e+06              67.0           3.346075e+17
# 29746  2.105473e+07              73.0           1.821234e+18
# 29747  2.105473e+07              73.0           1.126428e+18
# 29748  9.167329e+06              67.0           6.129877e+17
# 29749  1.055350e+06              46.0           8.221177e+15
#
#        market_cap_millions
# 7649             15.146200
# 7650            851.790371
# 7651            105.910065
# 7652            413.544035
# 7653            276.141727
# ...                    ...
# 29745             0.000000
# 29746             0.000000
# 29747             0.000000
# 29748             0.000000
# 29749             0.000000
#
# [770 rows x 24 columns]

# %%
print(df.iloc[80])
# Out:
# timeStamp                                                   2024-12-03 12:43:44
# hash                          0x4d95cc89f8e413a0fb50514f8128ac3f13e82fd9510c...
# from                                 0xb2170202b050f0549b9d9733f8258bc917346f98
# contractAddress                      0x6982508145454ce325ddbe47a25d4ec3d2311933
# to                                   0xedc6bacdc1e29d7c5fa6f6eca6fdd447b9c487c9
# tokenName                                                                  Pepe
# tokenSymbol                                                                PEPE
# value                                             45308077031390000000000000000
# dextools_price                                                         0.000022
# dextools_price5m                                                       0.000022
# dextools_variation5m                                                  -0.001837
# dextools_price1h                                                       0.000022
# dextools_variation1h                                                   0.205627
# dextools_price6h                                                       0.000022
# dextools_variation6h                                                   0.418773
# dextools_price24h                                                      0.000021
# dextools_variation24h                                                  4.995077
# dextools_circulatingSupply                                 413772823122434.6875
# dextools_totalSupply                                       413772823122434.6875
# dextools_mcap                                                 9069941043.473387
# dextools_fdv                                                  9069941043.473387
# dextools_holders                                                       342165.0
# transaction_value_usd                                993139263463358019403776.0
# market_cap_millions                                                 9069.941043
# Name: 7729, dtype: object

# %%
df = df[df["value"].astype(float) > 0]
df
# Out:
#                 timeStamp                                               hash  \
# 7649  2024-11-28 15:08:48  0x582629f26b088a43c651dc9a88aae9f5befb119dc6c6...
# 7650  2024-11-28 15:10:56  0x5ec2790bc316cad7c2c92c8058e199612553190c248e...
# 7651  2024-11-28 15:38:40  0x192a53111cc2655fb30b9f87baa42338ae75db7c3264...
# 29747  0x8b1396f754b83afa1d06d273d5915d573b4f04ee       Tesla AI    TESLA AI
# 29748  0x8b1396f754b83afa1d06d273d5915d573b4f04ee      Nvidia AI   NVIDIA AI
# 29749  0x8b1396f754b83afa1d06d273d5915d573b4f04ee  Haito Finance       HAITO
#
#                             value  dextools_price  dextools_price5m  ...  \
# 7649    3800000000000000000000000        0.126218          0.000000  ...
# 7650     240000000000000000000000        1.745558          0.000000  ...
# 7651    8000000000000000000000000        0.008827          0.007707  ...
# 7652   14638473810000000000000000        0.079256          0.079256  ...
# 7653     800000000000000000000000        0.069089          0.000000  ...
# ...                           ...             ...               ...  ...
# 29745        36500000000000000000        0.009167          0.000000  ...
# 29746        86500000000000000000        0.021055          0.000000  ...
# 29747        53500000000000000000        0.021055          0.000000  ...
# 29748        66866550000000000000        0.009167          0.000000  ...
# 29749        77900000000000000000        0.000106          0.000090  ...
#
#        dextools_variation6h  dextools_price24h  dextools_variation24h  \
# 7649               0.000000           0.106352              18.679720
# 7650              -2.409743           1.624130               7.476461
# 7651              -0.379260           0.007881              12.007352
# 7652               5.918223           0.072449               9.395056
# 7653              -2.897060           0.068820               0.390742
# ...                     ...                ...                    ...
# 29745              0.007888           0.006939              32.122045
# 29746              0.000000           0.017600              19.629760
# 29747              0.000000           0.017600              19.629760
# 29748              0.007888           0.006939              32.122045
# 29749             64.415603           0.000002            5302.538665
#
#        dextools_circulatingSupply  dextools_totalSupply  dextools_mcap  \
# 7649                 1.200000e+08          1.000000e+09   1.514620e+07
# 7650                 4.879761e+08          9.999981e+08   8.517904e+08
# 7651                 1.231841e+10          1.250000e+10   1.059101e+08
# 7652                 5.217818e+09          4.200000e+10   4.135440e+08
# 7653                 3.996915e+09          6.804870e+09   2.761417e+08
# ...                           ...                   ...            ...
# 29745                0.000000e+00          1.000000e+09   0.000000e+00
# 29746                0.000000e+00          1.000000e+09   0.000000e+00
# 29747                0.000000e+00          1.000000e+09   0.000000e+00
# 29748                0.000000e+00          1.000000e+09   0.000000e+00
# 29749                0.000000e+00          1.000000e+10   0.000000e+00
#
#        dextools_fdv  dextools_holders  transaction_value_usd  \
# 7649   1.262183e+08           17671.0           4.796297e+23
# 7650   1.745554e+09           40459.0           4.189338e+23
# 7651   1.074714e+08               0.0           7.061453e+22
# 7652   3.328757e+09           45172.0           1.160189e+24
# 7653   4.701398e+08           82670.0           5.527098e+22
# ...             ...               ...                    ...
# 29745  9.167329e+06              67.0           3.346075e+17
# 29746  2.105473e+07              73.0           1.821234e+18
# 29747  2.105473e+07              73.0           1.126428e+18
# 29748  9.167329e+06              67.0           6.129877e+17
# 29749  1.055350e+06              46.0           8.221177e+15
#
#        market_cap_millions
# 7649             15.146200
# 7650            851.790371
# 7651            105.910065
# 7652            413.544035
# 7653            276.141727
# ...                    ...
# 29745             0.000000
# 29746             0.000000
# 29747             0.000000
# 29748             0.000000
# 29749             0.000000
#
# [770 rows x 24 columns]

# %%
df.to_csv('token_dataframe.csv', index=False)
